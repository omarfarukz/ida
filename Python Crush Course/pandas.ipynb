# %%
# %pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np

# %%
lebel = [ 'a' ,'b', 'c']
my_data = [10,20,30]
arr = np.array(my_data)
d = {'a':10,'b':20,'c': 30}

# %%
pd.Series(data=my_data)
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
pd.Series(data = my_data, index=lebel)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
pd.Series(data=[sum, print, len])
# Out:
# 0      <built-in function sum>
# 1    <built-in function print>
# 2      <built-in function len>
# dtype: object

# %%
ser1= pd.Series([1,2,3,4], index= ['USA' , 'Germany', "BD" ," Japan"])

# %%
ser1
# Out:
# USA        1
# Germany    2
# BD         3
#  Japan     4
# dtype: int64

# %%
ser2= pd.Series([1,2,3,4], index= ['USA' , 'Germany', "Italy" ," Japan"])

# %%
ser2
# Out:
# USA        1
# Germany    2
# Italy      3
#  Japan     4
# dtype: int64

# %%
ser1["USA"]
# Out:
# np.int64(1)

# %%
ser2['Italy']
# Out:
# np.int64(3)

# %%
ser1+ser2
# Out:
#  Japan     8.0
# BD         NaN
# Germany    4.0
# Italy      NaN
# USA        2.0
# dtype: float64

# %%
from numpy.random import randn

# %%
np.random.seed(101)

# %%
df = pd.DataFrame(data= randn(5,4), index=['A', 'B','C','D','E'], columns= ['W', 'X', 'Y', 'Z'])

# %%
df
# Out:
#           W         X         Y         Z
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118 -0.319318 -0.848077  0.605965
# C -2.018168  0.740122  0.528813 -0.589001
# D  0.188695 -0.758872 -0.933237  0.955057
# E  0.190794  1.978757  2.605967  0.683509

# %%
df.head()
# Out:
#           W         X         Y         Z
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118 -0.319318 -0.848077  0.605965
# C -2.018168  0.740122  0.528813 -0.589001
# D  0.188695 -0.758872 -0.933237  0.955057
# E  0.190794  1.978757  2.605967  0.683509

# %%
df['W']
# Out:
# A    2.706850
# B    0.651118
# C   -2.018168
# D    0.188695
# E    0.190794
# Name: W, dtype: float64

# %%
df.X
# Out:
# A    0.628133
# B   -0.319318
# C    0.740122
# D   -0.758872
# E    1.978757
# Name: X, dtype: float64

# %%
df[['W','Y']]
# Out:
#           W         Y
# A  2.706850  0.907969
# B  0.651118 -0.848077
# C -2.018168  0.528813
# D  0.188695 -0.933237
# E  0.190794  2.605967

# %%
df['new_col']= df['W']+df['Y']

# %%
df
# Out:
#           W         X         Y         Z   new_col
# A  2.706850  0.628133  0.907969  0.503826  3.614819
# B  0.651118 -0.319318 -0.848077  0.605965 -0.196959
# C -2.018168  0.740122  0.528813 -0.589001 -1.489355
# D  0.188695 -0.758872 -0.933237  0.955057 -0.744542
# E  0.190794  1.978757  2.605967  0.683509  2.796762

# %%
df.drop('new_col', axis=1) # Axis 0 means raw and axis 1 value is column
# Out:
#           W         X         Y         Z
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118 -0.319318 -0.848077  0.605965
# C -2.018168  0.740122  0.528813 -0.589001
# D  0.188695 -0.758872 -0.933237  0.955057
# E  0.190794  1.978757  2.605967  0.683509

# %%
df
# Out:
#           W         X         Y         Z   new_col
# A  2.706850  0.628133  0.907969  0.503826  3.614819
# B  0.651118 -0.319318 -0.848077  0.605965 -0.196959
# C -2.018168  0.740122  0.528813 -0.589001 -1.489355
# D  0.188695 -0.758872 -0.933237  0.955057 -0.744542
# E  0.190794  1.978757  2.605967  0.683509  2.796762

# %%
df.drop('new_col', axis=1, inplace=True) # Permaninlty Delete

# %%
df
# Out:
#           W         X         Y         Z
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118 -0.319318 -0.848077  0.605965
# C -2.018168  0.740122  0.528813 -0.589001
# D  0.188695 -0.758872 -0.933237  0.955057
# E  0.190794  1.978757  2.605967  0.683509

# %%
df.shape # 1st one is row and 2nd one is total column index
# Out:
# (5, 4)

# %%
df.loc['C'] # lock means location
# Out:
# W   -2.018168
# X    0.740122
# Y    0.528813
# Z   -0.589001
# Name: C, dtype: float64

# %%
df.iloc[3]
# Out:
# W    0.188695
# X   -0.758872
# Y   -0.933237
# Z    0.955057
# Name: D, dtype: float64

# %%
df.loc['B']
# Out:
# W    0.651118
# X   -0.319318
# Y   -0.848077
# Z    0.605965
# Name: B, dtype: float64

# %%
df.loc[['A','B']]
# Out:
#           W         X         Y         Z
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118 -0.319318 -0.848077  0.605965

# %%
df.loc[['A',  'B'], ['W', 'Y']]
# Out:
#           W         Y
# A  2.706850  0.907969
# B  0.651118 -0.848077

# %%
## Panda's DataFrames Part 2

# %%
df
# Out:
#           W         X         Y         Z
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118 -0.319318 -0.848077  0.605965
# C -2.018168  0.740122  0.528813 -0.589001
# D  0.188695 -0.758872 -0.933237  0.955057
# E  0.190794  1.978757  2.605967  0.683509

# %%
df>0
# Out:
#        W      X      Y      Z
# A   True   True   True   True
# B   True  False  False   True
# C  False   True   True  False
# D   True  False  False   True
# E   True   True   True   True

# %%
df[df>0]
# Out:
#           W         X         Y         Z
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118       NaN       NaN  0.605965
# C       NaN  0.740122  0.528813       NaN
# D  0.188695       NaN       NaN  0.955057
# E  0.190794  1.978757  2.605967  0.683509

# %%
df['W']< 0
# Out:
# A    False
# B    False
# C     True
# D    False
# E    False
# Name: W, dtype: bool

# %%
df[df['W'] <0]
# Out:
#           W         X         Y         Z
# C -2.018168  0.740122  0.528813 -0.589001

# %%
out = df[df['Z']>0]

# %%
out
# Out:
#           W         X         Y         Z
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118 -0.319318 -0.848077  0.605965
# D  0.188695 -0.758872 -0.933237  0.955057
# E  0.190794  1.978757  2.605967  0.683509

# %%
out['W']
# Out:
# A    2.706850
# B    0.651118
# D    0.188695
# E    0.190794
# Name: W, dtype: float64

# %%
out[['W','Z']]
# Out:
#           W         Z
# A  2.706850  0.503826
# B  0.651118  0.605965
# D  0.188695  0.955057
# E  0.190794  0.683509

# %%
out.loc['A']
# Out:
# W    2.706850
# X    0.628133
# Y    0.907969
# Z    0.503826
# Name: A, dtype: float64

# %%
df
# Out:
#           W         X         Y         Z
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118 -0.319318 -0.848077  0.605965
# C -2.018168  0.740122  0.528813 -0.589001
# D  0.188695 -0.758872 -0.933237  0.955057
# E  0.190794  1.978757  2.605967  0.683509

# %%
df['W'] > 2
# Out:
# A     True
# B    False
# C    False
# D    False
# E    False
# Name: W, dtype: bool

# %%
df[df['W']>2]
# Out:
#          W         X         Y         Z
# A  2.70685  0.628133  0.907969  0.503826

# %%
(df['W'] > 2) & (df['Z'] > 0.5)
# Out:
# A     True
# B    False
# C    False
# D    False
# E    False
# dtype: bool

# %%
df[(df['W'] > 2) & (df['Z'] > 0.5)]
# Out:
#          W         X         Y         Z
# A  2.70685  0.628133  0.907969  0.503826

# %%
(df['W'] > 2) | (df['Z'] > 0.5)
# Out:
# A     True
# B     True
# C    False
# D     True
# E     True
# dtype: bool

# %%
df[(df['W'] > 2) & (df['Z'] > 0.5)]
# Out:
#          W         X         Y         Z
# A  2.70685  0.628133  0.907969  0.503826

# %%
df.reset_index() # for permanent inplace =true
# Out:
#   index         W         X         Y         Z
# 0     A  2.706850  0.628133  0.907969  0.503826
# 1     B  0.651118 -0.319318 -0.848077  0.605965
# 2     C -2.018168  0.740122  0.528813 -0.589001
# 3     D  0.188695 -0.758872 -0.933237  0.955057
# 4     E  0.190794  1.978757  2.605967  0.683509

# %%
df
# Out:
#           W         X         Y         Z
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118 -0.319318 -0.848077  0.605965
# C -2.018168  0.740122  0.528813 -0.589001
# D  0.188695 -0.758872 -0.933237  0.955057
# E  0.190794  1.978757  2.605967  0.683509

# %%
newind = 'CA NY WY OR CO'.split()

# %%
newind
# Out:
# ['CA', 'NY', 'WY', 'OR', 'CO']

# %%
df['states']= newind

# %%
df
# Out:
#           W         X         Y         Z states
# A  2.706850  0.628133  0.907969  0.503826     CA
# B  0.651118 -0.319318 -0.848077  0.605965     NY
# C -2.018168  0.740122  0.528813 -0.589001     WY
# D  0.188695 -0.758872 -0.933237  0.955057     OR
# E  0.190794  1.978757  2.605967  0.683509     CO

# %%
df.set_index('states')
# Out:
#                W         X         Y         Z
# states
# CA      2.706850  0.628133  0.907969  0.503826
# NY      0.651118 -0.319318 -0.848077  0.605965
# WY     -2.018168  0.740122  0.528813 -0.589001
# OR      0.188695 -0.758872 -0.933237  0.955057
# CO      0.190794  1.978757  2.605967  0.683509

# %%
df
# Out:
#           W         X         Y         Z states
# A  2.706850  0.628133  0.907969  0.503826     CA
# B  0.651118 -0.319318 -0.848077  0.605965     NY
# C -2.018168  0.740122  0.528813 -0.589001     WY
# D  0.188695 -0.758872 -0.933237  0.955057     OR
# E  0.190794  1.978757  2.605967  0.683509     CO

# %%
df.set_index('states',inplace=True)

# %%
df
# Out:
#                W         X         Y         Z
# states
# CA      2.706850  0.628133  0.907969  0.503826
# NY      0.651118 -0.319318 -0.848077  0.605965
# WY     -2.018168  0.740122  0.528813 -0.589001
# OR      0.188695 -0.758872 -0.933237  0.955057
# CO      0.190794  1.978757  2.605967  0.683509

# %%
df.reset_index()
# Out:
#   states         W         X         Y         Z
# 0     CA  2.706850  0.628133  0.907969  0.503826
# 1     NY  0.651118 -0.319318 -0.848077  0.605965
# 2     WY -2.018168  0.740122  0.528813 -0.589001
# 3     OR  0.188695 -0.758872 -0.933237  0.955057
# 4     CO  0.190794  1.978757  2.605967  0.683509

# %% [markdown]
# - Pandas DataFrame Part-3

# %%
import numpy as np
import pandas as pd
from numpy.random import rand

# %%
outside=['G1','G1','G1','G2','G2','G2',]
inside=[1,2,3,1,2,3]
heigher_index=list(zip(outside,inside))
heigher_index=pd.MultiIndex.from_tuples(heigher_index)

# %%
list(zip(outside, inside))
# Out:
# [('G1', 1), ('G1', 2), ('G1', 3), ('G2', 1), ('G2', 2), ('G2', 3)]

# %%
heigher_index
# Out:
# MultiIndex([('G1', 1),
#             ('G1', 2),
#             ('G1', 3),
#             ('G2', 1),
#             ('G2', 2),
#             ('G2', 3)],
#            )

# %%
df = pd.DataFrame(data= randn(6,2), index= heigher_index,columns=['A','B'])

# %%
df
# Out:
#              A         B
# G1 1 -0.497104 -0.754070
#    2 -0.943406  0.484752
#    3 -0.116773  1.901755
# G2 1  0.238127  1.996652
#    2 -0.993263  0.196800
#    3 -1.136645  0.000366

# %%
df.loc['G1']
# Out:
#           A         B
# 1 -0.497104 -0.754070
# 2 -0.943406  0.484752
# 3 -0.116773  1.901755

# %%
df.loc['G2']
# Out:
#           A         B
# 1  0.238127  1.996652
# 2 -0.993263  0.196800
# 3 -1.136645  0.000366

# %%
df.loc['G1'].loc[2]['B']
# Out:
# np.float64(0.48475164718163294)

# %%
df
# Out:
#              A         B
# G1 1 -0.497104 -0.754070
#    2 -0.943406  0.484752
#    3 -0.116773  1.901755
# G2 1  0.238127  1.996652
#    2 -0.993263  0.196800
#    3 -1.136645  0.000366

# %%
df.xs('G1')
# Out:
#           A         B
# 1 -0.497104 -0.754070
# 2 -0.943406  0.484752
# 3 -0.116773  1.901755

# %%
df.index.names
# Out:
# FrozenList([None, None])

# %%
df.index.names = ['Group','Num']

# %%
df
# Out:
#                   A         B
# Group Num
# G1    1   -0.497104 -0.754070
#       2   -0.943406  0.484752
#       3   -0.116773  1.901755
# G2    1    0.238127  1.996652
#       2   -0.993263  0.196800
#       3   -1.136645  0.000366

# %%
df.xs(1, level='')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/miniconda3/lib/python3.13/site-packages/pandas/core/indexes/multi.py:1683, in MultiIndex._get_level_number(self, level)
#    1682 try:
# -> 1683     level = self.names.index(level)
#    1684 except ValueError as err:
#
# ValueError: 'n' is not in list
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[127], line 1
# ----> 1 df.xs(1, level='n')
#
# File ~/miniconda3/lib/python3.13/site-packages/pandas/core/generic.py:4296, in NDFrame.xs(self, key, axis, level, drop_level)
#    4294 if not isinstance(labels, MultiIndex):
#    4295     raise TypeError("Index must be a MultiIndex")
# -> 4296 loc, new_ax = labels.get_loc_level(key, level=level, drop_level=drop_level)
#    4298 # create the tuple of the indexer
# ...

# %% [markdown]
# - Missing Data

# %% [markdown]
# - Group Data

# %%
data= {'Company': ['GooG', 'GooG', 'MSFT','MSFT', 'FB','FB'],
    'Peraon': ['Sam','Charlie', 'Amy','Vanessa', 'Carl', 'Sarah'],
       'Sales':[200,120,340,124,243,350]
      }

# %%
df= pd.DataFrame(data)

# %%
df
# Out:
#   Company   Peraon  Sales
# 0    GooG      Sam    200
# 1    GooG  Charlie    120
# 2    MSFT      Amy    340
# 3    MSFT  Vanessa    124
# 4      FB     Carl    243
# 5      FB    Sarah    350

# %%
bycomp=df.groupby('Company')

# %%
bycomp.mean(numeric_only=True)
# Out:
#          Sales
# Company
# FB       296.5
# GooG     160.0
# MSFT     232.0

# %%
bycomp.sum(numeric_only=True)
# Out:
#          Sales
# Company
# FB         593
# GooG       320
# MSFT       464

# %%
bycomp.sum(numeric_only=True).loc['FB']
# Out:
# Sales    593
# Name: FB, dtype: int64

# %%
df.groupby('Company').max()
# Out:
#           Peraon  Sales
# Company
# FB         Sarah    350
# GooG         Sam    200
# MSFT     Vanessa    340

# %%
df.groupby('Company').min()
# Out:
#           Peraon  Sales
# Company
# FB          Carl    243
# GooG     Charlie    120
# MSFT         Amy    124

# %%
df.groupby('Company').describe()
# Out:
#         Sales
#         count   mean         std    min     25%    50%     75%    max
# Company
# FB        2.0  296.5   75.660426  243.0  269.75  296.5  323.25  350.0
# GooG      2.0  160.0   56.568542  120.0  140.00  160.0  180.00  200.0
# MSFT      2.0  232.0  152.735065  124.0  178.00  232.0  286.00  340.0

# %%
df.groupby('Company').describe().loc['MSFT']
# Out:
# Sales  count      2.000000
#        mean     232.000000
#        std      152.735065
#        min      124.000000
#        25%      178.000000
#        50%      232.000000
#        75%      286.000000
#        max      340.000000
# Name: MSFT, dtype: float64

# %%
import pandas as pd

# %% [markdown]
# ## Merging, Joining and Concatenating

# %%
df1 = pd.DataFrame({
    'A':['A0', 'A1', 'A2', 'A3'],
    'B':['B0', 'B1', 'B2', 'B3'],
    'C':['C0', 'C1', 'C2', 'C3'],
    'D':['D0', 'D1', 'D2', 'D3']},
    index=[0,1,2,3])

# %%
df2 = pd.DataFrame({
    'A':['A4', 'A5', 'A6', 'A7'],
    'B':['B4', 'B5', 'B6', 'B7'],
    'C':['C4', 'C5', 'C6', 'C7'],
    'D':['D4', 'D5', 'D6', 'D7']},
    index=[4,5,6,7])

# %%
df3 = pd.DataFrame({
    'A':['A8', 'A9', 'A10', 'A11'],
    'B':['B8', 'B9', 'B10', 'B11'],
    'C':['C8', 'C9', 'C10', 'C11'],
    'D':['D8', 'D9', 'D10', 'D11']},
    index=[8,9,10,11])

# %%
df1
# Out:
#     A   B   C   D
# 0  A0  B0  C0  D0
# 1  A1  B1  C1  D1
# 2  A2  B2  C2  D2
# 3  A3  B3  C3  D3

# %%
df2
# Out:
#     A   B   C   D
# 4  A4  B4  C4  D4
# 5  A5  B5  C5  D5
# 6  A6  B6  C6  D6
# 7  A7  B7  C7  D7

# %%
df3
# Out:
#       A    B    C    D
# 8    A8   B8   C8   D8
# 9    A9   B9   C9   D9
# 10  A10  B10  C10  D10
# 11  A11  B11  C11  D11

# %%
pd.concat([df1,df2,df3]) #row wise
# Out:
#       A    B    C    D    A    B    C    D    A    B    C    D
# 0    A0   B0   C0   D0  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 1    A1   B1   C1   D1  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2    A2   B2   C2   D2  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 3    A3   B3   C3   D3  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4   NaN  NaN  NaN  NaN   A4   B4   C4   D4  NaN  NaN  NaN  NaN
# 5   NaN  NaN  NaN  NaN   A5   B5   C5   D5  NaN  NaN  NaN  NaN
# 6   NaN  NaN  NaN  NaN   A6   B6   C6   D6  NaN  NaN  NaN  NaN
# 7   NaN  NaN  NaN  NaN   A7   B7   C7   D7  NaN  NaN  NaN  NaN
# 8   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   A8   B8   C8   D8
# 9   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   A9   B9   C9   D9
# 10  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  A10  B10  C10  D10
# 11  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  A11  B11  C11  D11

# %%
pd.concat([df1,df2,df3],axis=1) #row wise
# Out:
#       A    B    C    D    A    B    C    D    A    B    C    D
# 0    A0   B0   C0   D0  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 1    A1   B1   C1   D1  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2    A2   B2   C2   D2  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 3    A3   B3   C3   D3  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4   NaN  NaN  NaN  NaN   A4   B4   C4   D4  NaN  NaN  NaN  NaN
# 5   NaN  NaN  NaN  NaN   A5   B5   C5   D5  NaN  NaN  NaN  NaN
# 6   NaN  NaN  NaN  NaN   A6   B6   C6   D6  NaN  NaN  NaN  NaN
# 7   NaN  NaN  NaN  NaN   A7   B7   C7   D7  NaN  NaN  NaN  NaN
# 8   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   A8   B8   C8   D8
# 9   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   A9   B9   C9   D9
# 10  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  A10  B10  C10  D10
# 11  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  A11  B11  C11  D11

# %%
left = pd.DataFrame({
    'key':['K0','K1','K2','K3'],
    'A': ['A0', 'A1', 'A2', 'A3'],
    'B': ['B0', 'B1', 'B2', 'B3']
})

# %%
right = pd.DataFrame({
    'key':['K0','K1','K2','K3'],
    'C': ['C0', 'C1', 'C2', 'C3'],
    'D': ['D0', 'D1', 'D2', 'D3']
})

# %%
left
# Out:
#   key   A   B
# 0  K0  A0  B0
# 1  K1  A1  B1
# 2  K2  A2  B2
# 3  K3  A3  B3

# %%
right
# Out:
#   key   C   D
# 0  K0  C0  D0
# 1  K1  C1  D1
# 2  K2  C2  D2
# 3  K3  C3  D3

# %%
pd.merge(left,right,how='inner', on='key')
# Out:
#   key   A   B   C   D
# 0  K0  A0  B0  C0  D0
# 1  K1  A1  B1  C1  D1
# 2  K2  A2  B2  C2  D2
# 3  K3  A3  B3  C3  D3

# %%
left = pd.DataFrame({
    'key1': ['K0', 'K0', 'K1', 'K2'],
    'key2':['K0', 'K1', 'K0', 'K1'],
    'A':['A0', 'A1', 'A2', 'A3'],
    'B':['B0', 'B1', 'B2', 'B3']
})

# %%
right = pd.DataFrame({
    'key1': ['K0', 'K1', 'K1', 'K2'],
    'key2':['K0', 'K0', 'K0', 'K0'],
    'C':['C0', 'C1', 'C2', 'C3'],
    'D':['D0', 'D1', 'D2', 'D3']
})

# %%
left
# Out:
#   key1 key2   A   B
# 0   K0   K0  A0  B0
# 1   K0   K1  A1  B1
# 2   K1   K0  A2  B2
# 3   K2   K1  A3  B3

# %%
right
# Out:
#   key1 key2   C   D
# 0   K0   K0  C0  D0
# 1   K1   K0  C1  D1
# 2   K1   K0  C2  D2
# 3   K2   K0  C3  D3

# %%
pd.merge(left, right,on=["key1","key2"])
# Out:
#   key1 key2   A   B   C   D
# 0   K0   K0  A0  B0  C0  D0
# 1   K1   K0  A2  B2  C1  D1
# 2   K1   K0  A2  B2  C2  D2

# %%
pd.merge(left, right,on=["key1","key2"],how='outer')
# Out:
#   key1 key2    A    B    C    D
# 0   K0   K0   A0   B0   C0   D0
# 1   K0   K1   A1   B1  NaN  NaN
# 2   K1   K0   A2   B2   C1   D1
# 3   K1   K0   A2   B2   C2   D2
# 4   K2   K0  NaN  NaN   C3   D3
# 5   K2   K1   A3   B3  NaN  NaN

# %% [markdown]
# ## Joining

# %%
left=pd.DataFrame({
    'A': ['A0','A1','A2'],
    'B': ['B0','B1','B2'],},
    index=['K0','K1','K2']
)

# %%
right=pd.DataFrame({
    'C':['C0','C1','C2'],
    'D':['D0','D1','D2']},
                   index=['K0','K2','K3']
)

# %%
left
# Out:
#      A   B
# K0  A0  B0
# K1  A1  B1
# K2  A2  B2

# %%
right
# Out:
#      C   D
# K0  C0  D0
# K2  C1  D1
# K3  C2  D2

# %%
left.join(right)
# Out:
#      A   B    C    D
# K0  A0  B0   C0   D0
# K1  A1  B1  NaN  NaN
# K2  A2  B2   C1   D1

# %%
left.join(right,how='outer')
# Out:
#       A    B    C    D
# K0   A0   B0   C0   D0
# K1   A1   B1  NaN  NaN
# K2   A2   B2   C1   D1
# K3  NaN  NaN   C2   D2

# %% [markdown]
# ## operations

# %%
left = pd.DataFrame({
    'A': ['A0', 'A1','A2'],
    'B': ['B0', 'B1', 'B2'],},
    index = ['K0', 'K1', 'K2'])

# %%
right = pd.DataFrame({
    'C': ['C0', 'C1','C2'],
    'D': ['D0', 'D1', 'D2'],},
    index = ['K0', 'K2', 'K3'])

# %%
df = pd.DataFrame({
    'col1':[1,2,3,4],
    'col2':[444,555,666,444],
    'col3':['abc', 'def', 'ghi', 'xyz']
})

# %%
df.head()
# Out:
#    col1  col2 col3
# 0     1   444  abc
# 1     2   555  def
# 2     3   666  ghi
# 3     4   444  xyz

# %%
df["col2"]
# Out:
# 0    444
# 1    555
# 2    666
# 3    444
# Name: col2, dtype: int64

# %%
df["col2"].unique()
# Out:
# array([444, 555, 666])

# %%
len(df["col2"].unique())
# Out:
# 3

# %%
df["col2"].value_counts()
# Out:
# col2
# 444    2
# 555    1
# 666    1
# Name: count, dtype: int64

# %%
df
# Out:
#    col1  col2 col3
# 0     1   444  abc
# 1     2   555  def
# 2     3   666  ghi
# 3     4   444  xyz

# %%
df["col1"]>2
# Out:
# 0    False
# 1    False
# 2     True
# 3     True
# Name: col1, dtype: bool

# %%
df["col2"] == 444
# Out:
# 0     True
# 1    False
# 2    False
# 3     True
# Name: col2, dtype: bool

# %%
df[(df["col1"]>2) & (df["col2"]==444)]
# Out:
#    col1  col2 col3
# 3     4   444  xyz

# %%
df['col1']
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# Name: col1, dtype: int64

# %%
def times2(x):
    return x*2

# %%
#lambda x:x*2

# %%
df['col1'].apply(times2)
# Out:
# 0    2
# 1    4
# 2    6
# 3    8
# Name: col1, dtype: int64

# %%
df["col3"].apply(len)
# Out:
# 0    3
# 1    3
# 2    3
# 3    3
# Name: col3, dtype: int64

# %%
df['col2'].apply(lambda x:x*2)
# Out:
# 0     888
# 1    1110
# 2    1332
# 3     888
# Name: col2, dtype: int64

# %%
df.sort_values(by='col2')
# Out:
#    col1  col2 col3
# 0     1   444  abc
# 3     4   444  xyz
# 1     2   555  def
# 2     3   666  ghi

# %%
df.isnull()
# Out:
#     col1   col2   col3
# 0  False  False  False
# 1  False  False  False
# 2  False  False  False
# 3  False  False  False

# %%
data = {
    'A':['foo', 'foo', 'foo', 'bar', 'bar', 'bar'],
    'B': ['one', 'one', 'two', 'two', 'one', 'one'],
    'C': ['x', 'y', 'x', 'y', 'x', 'y'],
    'D': [1,3,2,5,4,1]
}

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#      A    B  C  D
# 0  foo  one  x  1
# 1  foo  one  y  3
# 2  foo  two  x  2
# 3  bar  two  y  5
# 4  bar  one  x  4
# 5  bar  one  y  1

# %%
df.pivot_table(values='D',index=['A','B'],columns=['C'])
# Out:
# C          x    y
# A   B
# bar one  4.0  1.0
#     two  NaN  5.0
# foo one  1.0  3.0
#     two  2.0  NaN

# %% [markdown]
# ## Data input and Output

# %%
# !pip install sqlalchemy
# !pip install lxml
# !pip install html5lib
# !pip install BeautifulSoup4
# !pip install xlrd
# !pip install openpyxl
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.6/8.6 MB 8.3 MB/s eta 0:00:008.4 MB/s eta 0:00:01
# ...

# %%
pd.read_csv('example')
# Out:
#     a   b   c   d
# 0   0   1   2   3
# 1   4   5   6   7
# 2   8   9  10  11
# 3  12  13  14  15

# %%
df =pd.read_csv('example')

# %%
df
# Out:
#     a   b   c   d
# 0   0   1   2   3
# 1   4   5   6   7
# 2   8   9  10  11
# 3  12  13  14  15

# %%
df.to_csv('my_output')

# %%
pd.read_csv('my_output')
# Out:
#    Unnamed: 0   a   b   c   d
# 0           0   0   1   2   3
# 1           1   4   5   6   7
# 2           2   8   9  10  11
# 3           3  12  13  14  15

# %%
df.to_csv('my_output',index=False)

# %%
pd.read_csv('my_output')
# Out:
#     a   b   c   d
# 0   0   1   2   3
# 1   4   5   6   7
# 2   8   9  10  11
# 3  12  13  14  15

# %%
pd.read_excel('Excel_Sample.xlsx', sheet_name='Sheet1')
# Out:
#    Unnamed: 0   a   b   c   d
# 0           0   0   1   2   3
# 1           1   4   5   6   7
# 2           2   8   9  10  11
# 3           3  12  13  14  15

# %%
df =pd.read_excel('Excel_Sample.xlsx', sheet_name='Sheet1')

# %%
df.to_excel('my_excel.xlsx',sheet_name='new_sheet')

# %%
pd.read_excel('my_excel.xlsx',sheet_name='new_sheet')
# Out:
#    Unnamed: 0   a   b   c   d
# 0           0   0   1   2   3
# 1           1   4   5   6   7
# 2           2   8   9  10  11
# 3           3  12  13  14  15

# %%
data =pd.read_html('https://www.fdic.gov/bank-failures/failed-bank-list')

# %%
type(data)
# Out:
# list

# %%
data
# Out:
# [                                            Bank Name                City  \
#  0                        The Santa Anna National Bank          Santa Anna
#  1                                Pulaski Savings Bank             Chicago
#  2                  The First National Bank of Lindsay             Lindsay
#  3               Republic First Bank dba Republic Bank        Philadelphia
#  4                                       Citizens Bank            Sac City
#  5                            Heartland Tri-State Bank             Elkhart
#  6                                 First Republic Bank       San Francisco
#  7                                      Signature Bank            New York
#  8                                 Silicon Valley Bank         Santa Clara
#  9                                   Almena State Bank              Almena
#  10                         First City Bank of Florida   Fort Walton Beach
# ...

# %%
data[0]
# Out:
#                                             Bank Name                City  \
# 0                        The Santa Anna National Bank          Santa Anna
# 1                                Pulaski Savings Bank             Chicago
# 2                  The First National Bank of Lindsay             Lindsay
# 3               Republic First Bank dba Republic Bank        Philadelphia
# 4                                       Citizens Bank            Sac City
# 5                            Heartland Tri-State Bank             Elkhart
# 6                                 First Republic Bank       San Francisco
# 7                                      Signature Bank            New York
# 8                                 Silicon Valley Bank         Santa Clara
# 9                                   Almena State Bank              Almena
# 10                         First City Bank of Florida   Fort Walton Beach
# 11                               The First State Bank       Barboursville
# ...

# %%
from sqlalchemy import create_engine

# %%
engine= create_engine('sqlite:///memory:')

# %%
df.to_sql('my_sql', con=engine)
# Out:
# 4

# %%
df
# Out:
#     a   b   c   d
# 0   0   1   2   3
# 1   4   5   6   7
# 2   8   9  10  11
# 3  12  13  14  15

# %%
sqldf=pd.read_sql('my_sql',con=engine)

# %%
sqldf
# Out:
#    index   a   b   c   d
# 0      0   0   1   2   3
# 1      1   4   5   6   7
# 2      2   8   9  10  11
# 3      3  12  13  14  15
